# %%
# pip install numpy
# pip install pandas
# pip install matplot
import numpy as np
import pandas as pd 
# import matplot 

#50개 랜덤한 수 생성 , 0 ~ 1 사이 소수 중에서, 
data = np.random.rand(50)
print(type(data))
print(f"출력해보기 data : {data} ")

# 넘파이 -> 판다스의 시리즈 자료형으로 변환 
seri = pd.Series(data)
print(type(seri))
print(f"출력해보기 seri : \n {seri} ")

# 변환된 pd(테이블), 차트 그리기. 
seri.plot()
# Out:
# <class 'numpy.ndarray'>
# 출력해보기 data : [0.61392559 0.21645146 0.39308933 0.13248896 0.16962792 0.71336503
#  0.46564641 0.32957994 0.62559207 0.89791242 0.37573832 0.93341199
#  0.05535601 0.95091841 0.01936645 0.49911164 0.07398397 0.95368339
#  0.16625186 0.45812138 0.83145384 0.72411644 0.99167727 0.51214269
#  0.52545793 0.07895652 0.94011264 0.64621693 0.61175979 0.55166222
#  0.78333118 0.38423322 0.89459265 0.33087364 0.35538612 0.94441615
#  0.18370089 0.34098848 0.1015185  0.48118155 0.90151656 0.16658785
#  0.96988533 0.38843485 0.82550024 0.77248736 0.91022753 0.41852832
#  0.24651594 0.34620139]
# <class 'pandas.core.series.Series'>
# 출력해보기 seri :
#  0     0.613926
# 1     0.216451
# 2     0.393089
# 3     0.132489
# 4     0.169628
# 5     0.713365
# 6     0.465646
# 7     0.329580
# 8     0.625592
# 9     0.897912
# 10    0.375738
# 11    0.933412
# 12    0.055356
# 13    0.950918
# 14    0.019366
# 15    0.499112
# 16    0.073984
# 17    0.953683
# 18    0.166252
# ...
