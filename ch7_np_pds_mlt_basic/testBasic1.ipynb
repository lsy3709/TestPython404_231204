# %%
# pip install numpy
# pip install pandas
# pip install matplot
# matplotlib 공식 문서
# https://matplotlib.org/stable/index.html
import numpy as np
import pandas as pd 
import matplotlib

#50개 랜덤한 수 생성 , 0 ~ 1 사이 소수 중에서, 
data = np.random.rand(50)
print(type(data))
print(f"출력해보기 data : {data} ")

# 넘파이 -> 판다스의 시리즈 자료형으로 변환 
seri = pd.Series(data)
print(type(seri))
print(f"출력해보기 seri : \n {seri} ")

# 변환된 pd(테이블), 차트 그리기. 
# matplotlib 으로 스타일 변경해보기. 
matplotlib.style.use("ggplot")
seri.plot()
# Out:
# <class 'numpy.ndarray'>
# 출력해보기 data : [0.41224052 0.39295634 0.18296569 0.30256762 0.889561   0.28675401
#  0.18599818 0.9370954  0.10009409 0.11324839 0.67911818 0.94032075
#  0.34304859 0.55444453 0.99109178 0.92558942 0.25102842 0.33472569
#  0.73756767 0.56424725 0.0777652  0.85190094 0.84932966 0.09155649
#  0.07491826 0.83316734 0.14379977 0.87015124 0.40048014 0.76958322
#  0.9859544  0.99810306 0.16577966 0.04125184 0.41917097 0.87656219
#  0.8268895  0.94880344 0.10342561 0.40392767 0.89601602 0.29724403
#  0.54779588 0.69359299 0.14897534 0.69358638 0.04477188 0.95414761
#  0.19275913 0.17034113]
# <class 'pandas.core.series.Series'>
# 출력해보기 seri :
#  0     0.412241
# 1     0.392956
# 2     0.182966
# 3     0.302568
# 4     0.889561
# 5     0.286754
# 6     0.185998
# 7     0.937095
# 8     0.100094
# 9     0.113248
# 10    0.679118
# 11    0.940321
# 12    0.343049
# 13    0.554445
# 14    0.991092
# 15    0.925589
# 16    0.251028
# 17    0.334726
# 18    0.737568
# 19    0.564247
# 20    0.077765
# 21    0.851901
# 22    0.849330
# 23    0.091556
# 24    0.074918
# 25    0.833167
# 26    0.143800
# 27    0.870151
# 28    0.400480
# 29    0.769583
# 30    0.985954
# 31    0.998103
# 32    0.165780
# 33    0.041252
# 34    0.419171
# 35    0.876562
# 36    0.826890
# 37    0.948803
# 38    0.103426
# 39    0.403928
# 40    0.896016
# 41    0.297244
# 42    0.547796
# 43    0.693593
# 44    0.148975
# 45    0.693586
# 46    0.044772
# 47    0.954148
# 48    0.192759
# 49    0.170341
# dtype: float64
# <Axes: >

# %%
# matplotlib 공식 문서 예제 가져오기. 
import matplotlib.pyplot as plt
import numpy as np


species = ('Adelie', 'Chinstrap', 'Gentoo')
sex_counts = {
    'Male': np.array([73, 34, 61]),
    'Female': np.array([73, 34, 58]),
}
width = 0.6  # the width of the bars: can also be len(x) sequence


fig, ax = plt.subplots()
bottom = np.zeros(3)

for sex, sex_count in sex_counts.items():
    p = ax.bar(species, sex_count, width, label=sex, bottom=bottom)
    bottom += sex_count

    ax.bar_label(p, label_type='center')

ax.set_title('Number of penguins by sex')
ax.legend()

plt.show()

# %%
# np, Numpy -> 리스트 x , 배열 형식이고, 속도가 빨라서, 빅데이터 처리 도구로 많이 사용함. 
# pandas, -> 데이터 프레임, 엑셀 , 테이블(행, 열) 쉽게 처리하기 위한 도구로 사용이 됨. 
# matplotlib -> 시각화 하기위한 도구. 
import numpy as np
import pandas as pd 
import matplotlib
data_set = np.random.rand(10,3)
# print(f"data_set : \n {data_set}")
print(f"data_set 의 타입 : \n {type(data_set)}")
print(f"data_set 의 차원 : \n {data_set.shape}")

# 넘파이 요소 -> 판단스의 데이터 프레임에 넣기. 
df = pd.DataFrame(data_set, columns=["A", "B", "C"])
print(f"df 판단스의 데이터프레임. : \n {df}")
# Out:
# data_set 의 타입 :
#  <class 'numpy.ndarray'>
# data_set 의 차원 :
#  (10, 3)
# df 판단스의 데이터프레임. :
#            A         B         C
# 0  0.120027  0.104464  0.134958
# 1  0.578262  0.386530  0.389027
# 2  0.578215  0.641655  0.258005
# 3  0.848145  0.809139  0.947630
# 4  0.396425  0.651083  0.824139
# 5  0.705605  0.352949  0.360292
# 6  0.776298  0.434659  0.360319
# 7  0.716869  0.409721  0.095505
# 8  0.363339  0.419029  0.488145
# 9  0.909884  0.845707  0.926775
