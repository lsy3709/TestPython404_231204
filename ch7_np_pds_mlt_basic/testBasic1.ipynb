# %%
# pip install numpy
# pip install pandas
# pip install matplot
import numpy as np
import pandas as pd 
# import matplot 

#50개 랜덤한 수 생성 , 0 ~ 1 사이 소수 중에서, 
data = np.random.rand(50)
print(type(data))
print(f"출력해보기 data : {data} ")

# 넘파이 -> 판다스의 시리즈 자료형으로 변환 
seri = pd.Series(data)
print(type(seri))
print(f"출력해보기 seri : \n {seri} ")
# Out:
# <class 'numpy.ndarray'>
# 출력해보기 data : [0.10945706 0.86366674 0.8262702  0.83481613 0.10839848 0.80568342
#  0.67837394 0.87145457 0.73331426 0.28203633 0.78046262 0.46703888
#  0.04187905 0.58808139 0.17569733 0.59276806 0.22614358 0.25077793
#  0.34955384 0.89384947 0.09317464 0.44746699 0.8900312  0.020139
#  0.68605633 0.36212394 0.47884683 0.98596991 0.72282575 0.7938173
#  0.45454122 0.77457988 0.63700956 0.35516456 0.03038368 0.24007073
#  0.29332179 0.34921603 0.34225427 0.87967523 0.34309133 0.82152352
#  0.45933355 0.13851142 0.01527972 0.07855782 0.5522595  0.90181859
#  0.6242097  0.901472  ]
# <class 'pandas.core.series.Series'>
# 출력해보기 seri :
#  0     0.109457
# 1     0.863667
# 2     0.826270
# 3     0.834816
# 4     0.108398
# 5     0.805683
# 6     0.678374
# 7     0.871455
# 8     0.733314
# 9     0.282036
# 10    0.780463
# 11    0.467039
# 12    0.041879
# 13    0.588081
# 14    0.175697
# 15    0.592768
# 16    0.226144
# 17    0.250778
# 18    0.349554
# ...
