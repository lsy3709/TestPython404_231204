# %%
# pip install selenium 
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome()
driver.get('https://google.com')
# r = driver.execute_script('return 100*50')
# print(r)
driver.get("https://www.youtube.com/c/paikscuisine/videos")
all_videos = driver.find_elements(By.ID, "dismissible")
print(all_videos)

time.sleep(2)
datas = []
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_11")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_18")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_25")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_31")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_49")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_50")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_51")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_52")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_53")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_54")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_55")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_56")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_57")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_58")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_59")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_60")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_61")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_62")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_63")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_64")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_65")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_66")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_67")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_68")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_69")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e909a74b0cf7463f2d41", element="96258D9C04089CC4068484DEE7CC6BEA_element_70")>, <selenium.webdriver.remote.webelement.WebElement (session="47902110cf92e9 ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import urllib.request

# chrome_options = webdriver.ChromeOptions()
# chrome_options.binary = 'C://chromedriver_win32/chromedriver.exe' # 드라이버 실행파일 경로
query = '춘식이'
driver = webdriver.Chrome()
driver.get(f'https://www.google.com/imghp')
# 구글 이미지 검색창 이름이 : q
search_bar = driver.find_element(By.NAME,"q")
# 검색 키워드를 춘식이 설정
search_bar.send_keys(query)
# 전달. 
search_bar.submit()
# 잠시 대기 시간 ms 1000ms = 1초 
PAUSE_TIME = 2
# 현재 문서의 스크롤의 높이를 표시. 
last_hegiht = driver.execute_script("return window.scrollY")
print(f"처음 last_hegiht : {last_hegiht}")
new_height = 0

interval = 2
prev_height = driver.execute_script("return document.body.scrollHeight")

    #  결과 더보기 버튼 .LZ4I
    #     resultMoreBtn = driver.find_element(By.CSS_SELECTOR,".LZ4I")
    #     resultMoreBtn.click()
    #     continue

while True:
    #화면 가장 아래로 스크롤 내리기
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(interval)

    curr_height = driver.execute_script("return document.body.scrollHeight")
    if curr_height == prev_height:
        break
    
    prev_height = curr_height


# while True :
#     # 스크롤 50px 아래로 이동 수행. 
#     driver.execute_script("window.scrollTo(0,500)")
#     last_hegiht2 = driver.execute_script("return document.body.scrollHeight")
#     print(f"스크롤 이동 명령후 길이 조회 : {last_hegiht2}")
#     # 2 ms 대기
#     time.sleep(PAUSE_TIME)
#     # 이동 후,  스크롤 높이 
#     new_height = driver.execute_script("return document.body.scrollHeight")
#     print(f"반복 new_height : {new_height}")
#     # 스크롤 이동 후 높이가, 크다면 이동했다면
#     if new_height - last_hegiht > 0 :
#         # 지난 높이에 대입.
#         last_hegiht = new_height
#         # 다시 반복문으로 돌아가 다시, 50px 내림 
 
#         continue
#     # elif new_height - last_hegiht == 0 :
#     #     # 결과 더보기 버튼 .LZ4I
#     #     resultMoreBtn = driver.find_element(By.CSS_SELECTOR,".LZ4I")
#     #     resultMoreBtn.click()
#     #     continue
#     else :
#         break
#     # 해당 스크롤을 다 내린후, 해당 이미지의 CSS_SELECTOR 를 이용해, 해당 클래스 모두를
#     # 추출해서 리스트에 담음
img_elements = driver.find_elements(By.CSS_SELECTOR,".rg_i")
# 다시 이미지만 추출해서 담음 임시 리스트 
imgs = []
# enumerate 함수 이용하면 해당 인덱스도 같이 추출 가능. 
for idx, img in enumerate(img_elements) :
    print(f"{query} : {idx+1}/{len(img_elements)} proceed...")
    try :
        # 이미지 클릭
        img.click()
        # 잠시 대기 
        time.sleep(PAUSE_TIME)
        # 이부분에서 에러나면, 직접 개발자 도구 활용해서 XPATH 추출한 뒤에 변경
        
        img_src = img.get_attribute('src')
        img_alt = img.get_attribute('alt')
        imgs.append({
            'alt' : img_alt,
            'src' : img_src
        })
        
    except :
        print(f'err in {idx}')
        pass
driver.close()
save_path = f'C:\ccestcrawl\{query}'
import os
if not os.path.exists(save_path):
    os.mkdir(save_path)
total_N = len(imgs)
for idx, one in enumerate(imgs):
    src = one['src']
    alt = one['alt']
    urllib.request.urlretrieve(src,  f"{save_path}\{query}_{idx}.png")
    print(idx, alt)
print('done')
# Out:
# <string>:94: SyntaxWarning: invalid escape sequence '\{'
# <string>:102: SyntaxWarning: invalid escape sequence '\{'
# <>:94: SyntaxWarning: invalid escape sequence '\{'
# <>:94: SyntaxWarning: invalid escape sequence '\c'
# <>:102: SyntaxWarning: invalid escape sequence '\{'
# <string>:94: SyntaxWarning: invalid escape sequence '\{'
# <string>:102: SyntaxWarning: invalid escape sequence '\{'
# <>:94: SyntaxWarning: invalid escape sequence '\{'
# <>:94: SyntaxWarning: invalid escape sequence '\c'
# <>:102: SyntaxWarning: invalid escape sequence '\{'
# C:\Users\it\AppData\Local\Temp\ipykernel_17744\3927680840.py:94: SyntaxWarning: invalid escape sequence '\{'
#   save_path = f'C:\ccestcrawl\{query}'
# C:\Users\it\AppData\Local\Temp\ipykernel_17744\3927680840.py:94: SyntaxWarning: invalid escape sequence '\c'
#   save_path = f'C:\ccestcrawl\{query}'
# C:\Users\it\AppData\Local\Temp\ipykernel_17744\3927680840.py:102: SyntaxWarning: invalid escape sequence '\{'
#   urllib.request.urlretrieve(src,  f"{save_path}\{query}_{idx}.png")
# 처음 last_hegiht : 0
# 춘식이 : 1/399 proceed...
# 춘식이 : 2/399 proceed...
# 춘식이 : 3/399 proceed...
# 춘식이 : 4/399 proceed...
# 춘식이 : 5/399 proceed...
# 춘식이 : 6/399 proceed...
# 춘식이 : 7/399 proceed...
# 춘식이 : 8/399 proceed...
# 춘식이 : 9/399 proceed...
# 춘식이 : 10/399 proceed...
# 춘식이 : 11/399 proceed...
# 춘식이 : 12/399 proceed...
# 춘식이 : 13/399 proceed...
# err in 12
# 춘식이 : 14/399 proceed...
# err in 13
# 춘식이 : 15/399 proceed...
# 춘식이 : 16/399 proceed...
# 춘식이 : 17/399 proceed...
# err in 16
# 춘식이 : 18/399 proceed...
# 춘식이 : 19/399 proceed...
# 춘식이 : 20/399 proceed...
# 춘식이 : 21/399 proceed...
# err in 20
# 춘식이 : 22/399 proceed...
# err in 21
# 춘식이 : 23/399 proceed...
# 춘식이 : 24/399 proceed...
# err in 23
# 춘식이 : 25/399 proceed...
# 춘식이 : 26/399 proceed...
# 춘식이 : 27/399 proceed...
# 춘식이 : 28/399 proceed...
# 춘식이 : 29/399 proceed...
# 춘식이 : 30/399 proceed...
# 춘식이 : 31/399 proceed...
# 춘식이 : 32/399 proceed...
# err in 31
# 춘식이 : 33/399 proceed...
# 춘식이 : 34/399 proceed...
# 춘식이 : 35/399 proceed...
# 춘식이 : 36/399 proceed...
# 춘식이 : 37/399 proceed...
# 춘식이 : 38/399 proceed...
# err in 37
# 춘식이 : 39/399 proceed...
# err in 38
# 춘식이 : 40/399 proceed...
# 춘식이 : 41/399 proceed...
# 춘식이 : 42/399 proceed...
# 춘식이 : 43/399 proceed...
# 춘식이 : 44/399 proceed...
# 춘식이 : 45/399 proceed...
# 춘식이 : 46/399 proceed...
# 춘식이 : 47/399 proceed...
# 춘식이 : 48/399 proceed...
# err in 47
# 춘식이 : 49/399 proceed...
# 춘식이 : 50/399 proceed...
# 춘식이 : 51/399 proceed...
# 춘식이 : 52/399 proceed...
# 춘식이 : 53/399 proceed...
# 춘식이 : 54/399 proceed...
# 춘식이 : 55/399 proceed...
# 춘식이 : 56/399 proceed...
# 춘식이 : 57/399 proceed...
# err in 56
# 춘식이 : 58/399 proceed...
# 춘식이 : 59/399 proceed...
# err in 58
# 춘식이 : 60/399 proceed...
# err in 59
# 춘식이 : 61/399 proceed...
# 춘식이 : 62/399 proceed...
# 춘식이 : 63/399 proceed...
# err in 62
# 춘식이 : 64/399 proceed...
# err in 63
# 춘식이 : 65/399 proceed...
# 춘식이 : 66/399 proceed...
# 춘식이 : 67/399 proceed...
# err in 66
# 춘식이 : 68/399 proceed...
# 춘식이 : 69/399 proceed...
# err in 68
# 춘식이 : 70/399 proceed...
# err in 69
# 춘식이 : 71/399 proceed...
# err in 70
# 춘식이 : 72/399 proceed...
# err in 71
# 춘식이 : 73/399 proceed...
# err in 72
# 춘식이 : 74/399 proceed...
# err in 73
# 춘식이 : 75/399 proceed...
# err in 74
# 춘식이 : 76/399 proceed...
# err in 75
# 춘식이 : 77/399 proceed...
# 춘식이 : 78/399 proceed...
# 춘식이 : 79/399 proceed...
# err in 78
# 춘식이 : 80/399 proceed...
# err in 79
# 춘식이 : 81/399 proceed...
# 춘식이 : 82/399 proceed...
# 춘식이 : 83/399 proceed...
# 춘식이 : 84/399 proceed...
# 춘식이 : 85/399 proceed...
# err in 84
# 춘식이 : 86/399 proceed...
# 춘식이 : 87/399 proceed...
# 춘식이 : 88/399 proceed...
# 춘식이 : 89/399 proceed...
# 춘식이 : 90/399 proceed...
# 춘식이 : 91/399 proceed...
# 춘식이 : 92/399 proceed...
# 춘식이 : 93/399 proceed...
# 춘식이 : 94/399 proceed...
# 춘식이 : 95/399 proceed...
# err in 94
# 춘식이 : 96/399 proceed...
# 춘식이 : 97/399 proceed...
# 춘식이 : 98/399 proceed...
# 춘식이 : 99/399 proceed...
# 춘식이 : 100/399 proceed...
# 춘식이 : 101/399 proceed...
# 춘식이 : 102/399 proceed...
# 춘식이 : 103/399 proceed...
# 춘식이 : 104/399 proceed...
# 춘식이 : 105/399 proceed...
# 춘식이 : 106/399 proceed...
# 춘식이 : 107/399 proceed...
# 춘식이 : 108/399 proceed...
# err in 107
# 춘식이 : 109/399 proceed...
# err in 108
# 춘식이 : 110/399 proceed...
# 춘식이 : 111/399 proceed...
# 춘식이 : 112/399 proceed...
# 춘식이 : 113/399 proceed...
# 춘식이 : 114/399 proceed...
# 춘식이 : 115/399 proceed...
# err in 114
# 춘식이 : 116/399 proceed...
# 춘식이 : 117/399 proceed...
# 춘식이 : 118/399 proceed...
# 춘식이 : 119/399 proceed...
# err in 118
# 춘식이 : 120/399 proceed...
# err in 119
# 춘식이 : 121/399 proceed...
# 춘식이 : 122/399 proceed...
# err in 121
# 춘식이 : 123/399 proceed...
# err in 122
# 춘식이 : 124/399 proceed...
# err in 123
# 춘식이 : 125/399 proceed...
# err in 124
# 춘식이 : 126/399 proceed...
# err in 125
# 춘식이 : 127/399 proceed...
# err in 126
# 춘식이 : 128/399 proceed...
# err in 127
# 춘식이 : 129/399 proceed...
# err in 128
# 춘식이 : 130/399 proceed...
# err in 129
# 춘식이 : 131/399 proceed...
# err in 130
# 춘식이 : 132/399 proceed...
# err in 131
# 춘식이 : 133/399 proceed...
# err in 132
# 춘식이 : 134/399 proceed...
# err in 133
# 춘식이 : 135/399 proceed...
# err in 134
# 춘식이 : 136/399 proceed...
# err in 135
# 춘식이 : 137/399 proceed...
# err in 136
# 춘식이 : 138/399 proceed...
# err in 137
# 춘식이 : 139/399 proceed...
# err in 138
# 춘식이 : 140/399 proceed...
# err in 139
# 춘식이 : 141/399 proceed...
# err in 140
# 춘식이 : 142/399 proceed...
# err in 141
# 춘식이 : 143/399 proceed...
# err in 142
# 춘식이 : 144/399 proceed...
# err in 143
# 춘식이 : 145/399 proceed...
# err in 144
# 춘식이 : 146/399 proceed...
# err in 145
# 춘식이 : 147/399 proceed...
# err in 146
# 춘식이 : 148/399 proceed...
# err in 147
# 춘식이 : 149/399 proceed...
# err in 148
# 춘식이 : 150/399 proceed...
# err in 149
# 춘식이 : 151/399 proceed...
# err in 150
# 춘식이 : 152/399 proceed...
# err in 151
# 춘식이 : 153/399 proceed...
# err in 152
# 춘식이 : 154/399 proceed...
# err in 153
# 춘식이 : 155/399 proceed...
# err in 154
# 춘식이 : 156/399 proceed...
# err in 155
# 춘식이 : 157/399 proceed...
# err in 156
# 춘식이 : 158/399 proceed...
# err in 157
# 춘식이 : 159/399 proceed...
# err in 158
# 춘식이 : 160/399 proceed...
# err in 159
# 춘식이 : 161/399 proceed...
# err in 160
# 춘식이 : 162/399 proceed...
# err in 161
# 춘식이 : 163/399 proceed...
# err in 162
# 춘식이 : 164/399 proceed...
# err in 163
# 춘식이 : 165/399 proceed...
# err in 164
# 춘식이 : 166/399 proceed...
# err in 165
# 춘식이 : 167/399 proceed...
# err in 166
# 춘식이 : 168/399 proceed...
# err in 167
# 춘식이 : 169/399 proceed...
# err in 168
# 춘식이 : 170/399 proceed...
# err in 169
# 춘식이 : 171/399 proceed...
# err in 170
# 춘식이 : 172/399 proceed...
# err in 171
# 춘식이 : 173/399 proceed...
# err in 172
# 춘식이 : 174/399 proceed...
# err in 173
# 춘식이 : 175/399 proceed...
# 춘식이 : 176/399 proceed...
# 춘식이 : 177/399 proceed...
# 춘식이 : 178/399 proceed...
# 춘식이 : 179/399 proceed...
# err in 178
# 춘식이 : 180/399 proceed...
# err in 179
# 춘식이 : 181/399 proceed...
# 춘식이 : 182/399 proceed...
# 춘식이 : 183/399 proceed...
# 춘식이 : 184/399 proceed...
# 춘식이 : 185/399 proceed...
# 춘식이 : 186/399 proceed...
# 춘식이 : 187/399 proceed...
# err in 186
# 춘식이 : 188/399 proceed...
# err in 187
# 춘식이 : 189/399 proceed...
# 춘식이 : 190/399 proceed...
# 춘식이 : 191/399 proceed...
# err in 190
# 춘식이 : 192/399 proceed...
# 춘식이 : 193/399 proceed...
# 춘식이 : 194/399 proceed...
# 춘식이 : 195/399 proceed...
# 춘식이 : 196/399 proceed...
# err in 195
# 춘식이 : 197/399 proceed...
# 춘식이 : 198/399 proceed...
# 춘식이 : 199/399 proceed...
# 춘식이 : 200/399 proceed...
# err in 199
# 춘식이 : 201/399 proceed...
# err in 200
# 춘식이 : 202/399 proceed...
# 춘식이 : 203/399 proceed...
# 춘식이 : 204/399 proceed...
# 춘식이 : 205/399 proceed...
# 춘식이 : 206/399 proceed...
# err in 205
# 춘식이 : 207/399 proceed...
# 춘식이 : 208/399 proceed...
# err in 207
# 춘식이 : 209/399 proceed...
# err in 208
# 춘식이 : 210/399 proceed...
# 춘식이 : 211/399 proceed...
# 춘식이 : 212/399 proceed...
# 춘식이 : 213/399 proceed...
# 춘식이 : 214/399 proceed...
# 춘식이 : 215/399 proceed...
# 춘식이 : 216/399 proceed...
# err in 215
# 춘식이 : 217/399 proceed...
# err in 216
# 춘식이 : 218/399 proceed...
# 춘식이 : 219/399 proceed...
# 춘식이 : 220/399 proceed...
# err in 219
# 춘식이 : 221/399 proceed...
# err in 220
# 춘식이 : 222/399 proceed...
# err in 221
# 춘식이 : 223/399 proceed...
# err in 222
# 춘식이 : 224/399 proceed...
# err in 223
# 춘식이 : 225/399 proceed...
# err in 224
# 춘식이 : 226/399 proceed...
# err in 225
# 춘식이 : 227/399 proceed...
# err in 226
# 춘식이 : 228/399 proceed...
# err in 227
# 춘식이 : 229/399 proceed...
# err in 228
# 춘식이 : 230/399 proceed...
# err in 229
# 춘식이 : 231/399 proceed...
# err in 230
# 춘식이 : 232/399 proceed...
# err in 231
# 춘식이 : 233/399 proceed...
# err in 232
# 춘식이 : 234/399 proceed...
# err in 233
# 춘식이 : 235/399 proceed...
# err in 234
# 춘식이 : 236/399 proceed...
# err in 235
# 춘식이 : 237/399 proceed...
# err in 236
# 춘식이 : 238/399 proceed...
# err in 237
# 춘식이 : 239/399 proceed...
# err in 238
# 춘식이 : 240/399 proceed...
# err in 239
# 춘식이 : 241/399 proceed...
# err in 240
# 춘식이 : 242/399 proceed...
# err in 241
# 춘식이 : 243/399 proceed...
# err in 242
# 춘식이 : 244/399 proceed...
# err in 243
# 춘식이 : 245/399 proceed...
# err in 244
# 춘식이 : 246/399 proceed...
# err in 245
# 춘식이 : 247/399 proceed...
# err in 246
# 춘식이 : 248/399 proceed...
# err in 247
# 춘식이 : 249/399 proceed...
# err in 248
# 춘식이 : 250/399 proceed...
# err in 249
# 춘식이 : 251/399 proceed...
# err in 250
# 춘식이 : 252/399 proceed...
# err in 251
# 춘식이 : 253/399 proceed...
# err in 252
# 춘식이 : 254/399 proceed...
# err in 253
# 춘식이 : 255/399 proceed...
# err in 254
# 춘식이 : 256/399 proceed...
# err in 255
# 춘식이 : 257/399 proceed...
# err in 256
# 춘식이 : 258/399 proceed...
# err in 257
# 춘식이 : 259/399 proceed...
# err in 258
# 춘식이 : 260/399 proceed...
# err in 259
# 춘식이 : 261/399 proceed...
# err in 260
# 춘식이 : 262/399 proceed...
# err in 261
# 춘식이 : 263/399 proceed...
# err in 262
# 춘식이 : 264/399 proceed...
# err in 263
# 춘식이 : 265/399 proceed...
# err in 264
# 춘식이 : 266/399 proceed...
# err in 265
# 춘식이 : 267/399 proceed...
# err in 266
# 춘식이 : 268/399 proceed...
# err in 267
# 춘식이 : 269/399 proceed...
# err in 268
# 춘식이 : 270/399 proceed...
# err in 269
# 춘식이 : 271/399 proceed...
# err in 270
# 춘식이 : 272/399 proceed...
# err in 271
# 춘식이 : 273/399 proceed...
# 춘식이 : 274/399 proceed...
# 춘식이 : 275/399 proceed...
# 춘식이 : 276/399 proceed...
# err in 275
# 춘식이 : 277/399 proceed...
# 춘식이 : 278/399 proceed...
# err in 277
# 춘식이 : 279/399 proceed...
# err in 278
# 춘식이 : 280/399 proceed...
# 춘식이 : 281/399 proceed...
# 춘식이 : 282/399 proceed...
# err in 281
# 춘식이 : 283/399 proceed...
# 춘식이 : 284/399 proceed...
# 춘식이 : 285/399 proceed...
# err in 284
# 춘식이 : 286/399 proceed...
# err in 285
# 춘식이 : 287/399 proceed...
# 춘식이 : 288/399 proceed...
# 춘식이 : 289/399 proceed...
# 춘식이 : 290/399 proceed...
# 춘식이 : 291/399 proceed...
# 춘식이 : 292/399 proceed...
# 춘식이 : 293/399 proceed...
# 춘식이 : 294/399 proceed...
# 춘식이 : 295/399 proceed...
# 춘식이 : 296/399 proceed...
# 춘식이 : 297/399 proceed...
# err in 296
# 춘식이 : 298/399 proceed...
# 춘식이 : 299/399 proceed...
# 춘식이 : 300/399 proceed...
# 춘식이 : 301/399 proceed...
# 춘식이 : 302/399 proceed...
# 춘식이 : 303/399 proceed...
# 춘식이 : 304/399 proceed...
# 춘식이 : 305/399 proceed...
# 춘식이 : 306/399 proceed...
# 춘식이 : 307/399 proceed...
# 춘식이 : 308/399 proceed...
# 춘식이 : 309/399 proceed...
# 춘식이 : 310/399 proceed...
# 춘식이 : 311/399 proceed...
# 춘식이 : 312/399 proceed...
# err in 311
# 춘식이 : 313/399 proceed...
# 춘식이 : 314/399 proceed...
# 춘식이 : 315/399 proceed...
# err in 314
# 춘식이 : 316/399 proceed...
# 춘식이 : 317/399 proceed...
# err in 316
# 춘식이 : 318/399 proceed...
# err in 317
# 춘식이 : 319/399 proceed...
# 춘식이 : 320/399 proceed...
# 춘식이 : 321/399 proceed...
# 춘식이 : 322/399 proceed...
# err in 321
# 춘식이 : 323/399 proceed...
# err in 322
# 춘식이 : 324/399 proceed...
# err in 323
# 춘식이 : 325/399 proceed...
# err in 324
# 춘식이 : 326/399 proceed...
# err in 325
# 춘식이 : 327/399 proceed...
# err in 326
# 춘식이 : 328/399 proceed...
# err in 327
# 춘식이 : 329/399 proceed...
# err in 328
# 춘식이 : 330/399 proceed...
# err in 329
# 춘식이 : 331/399 proceed...
# err in 330
# 춘식이 : 332/399 proceed...
# err in 331
# 춘식이 : 333/399 proceed...
# err in 332
# 춘식이 : 334/399 proceed...
# err in 333
# 춘식이 : 335/399 proceed...
# err in 334
# 춘식이 : 336/399 proceed...
# err in 335
# 춘식이 : 337/399 proceed...
# err in 336
# 춘식이 : 338/399 proceed...
# err in 337
# 춘식이 : 339/399 proceed...
# err in 338
# 춘식이 : 340/399 proceed...
# err in 339
# 춘식이 : 341/399 proceed...
# err in 340
# 춘식이 : 342/399 proceed...
# err in 341
# 춘식이 : 343/399 proceed...
# err in 342
# 춘식이 : 344/399 proceed...
# err in 343
# 춘식이 : 345/399 proceed...
# err in 344
# 춘식이 : 346/399 proceed...
# err in 345
# 춘식이 : 347/399 proceed...
# err in 346
# 춘식이 : 348/399 proceed...
# err in 347
# 춘식이 : 349/399 proceed...
# err in 348
# 춘식이 : 350/399 proceed...
# err in 349
# 춘식이 : 351/399 proceed...
# err in 350
# 춘식이 : 352/399 proceed...
# err in 351
# 춘식이 : 353/399 proceed...
# err in 352
# 춘식이 : 354/399 proceed...
# err in 353
# 춘식이 : 355/399 proceed...
# err in 354
# 춘식이 : 356/399 proceed...
# err in 355
# 춘식이 : 357/399 proceed...
# err in 356
# 춘식이 : 358/399 proceed...
# err in 357
# 춘식이 : 359/399 proceed...
# err in 358
# 춘식이 : 360/399 proceed...
# err in 359
# 춘식이 : 361/399 proceed...
# err in 360
# 춘식이 : 362/399 proceed...
# err in 361
# 춘식이 : 363/399 proceed...
# err in 362
# 춘식이 : 364/399 proceed...
# err in 363
# 춘식이 : 365/399 proceed...
# err in 364
# 춘식이 : 366/399 proceed...
# err in 365
# 춘식이 : 367/399 proceed...
# err in 366
# 춘식이 : 368/399 proceed...
# err in 367
# 춘식이 : 369/399 proceed...
# err in 368
# 춘식이 : 370/399 proceed...
# err in 369
# 춘식이 : 371/399 proceed...
# 춘식이 : 372/399 proceed...
# 춘식이 : 373/399 proceed...
# err in 372
# 춘식이 : 374/399 proceed...
# 춘식이 : 375/399 proceed...
# 춘식이 : 376/399 proceed...
# 춘식이 : 377/399 proceed...
# 춘식이 : 378/399 proceed...
# 춘식이 : 379/399 proceed...
# err in 378
# 춘식이 : 380/399 proceed...
# err in 379
# 춘식이 : 381/399 proceed...
# 춘식이 : 382/399 proceed...
# err in 381
# 춘식이 : 383/399 proceed...
# err in 382
# 춘식이 : 384/399 proceed...
# 춘식이 : 385/399 proceed...
# 춘식이 : 386/399 proceed...
# 춘식이 : 387/399 proceed...
# err in 386
# 춘식이 : 388/399 proceed...
# 춘식이 : 389/399 proceed...
# 춘식이 : 390/399 proceed...
# 춘식이 : 391/399 proceed...
# err in 390
# 춘식이 : 392/399 proceed...
# err in 391
# 춘식이 : 393/399 proceed...
# 춘식이 : 394/399 proceed...
# err in 393
# 춘식이 : 395/399 proceed...
# err in 394
# 춘식이 : 396/399 proceed...
# 춘식이 : 397/399 proceed...
# 춘식이 : 398/399 proceed...
# 춘식이 : 399/399 proceed...
# 0 카카오프렌즈의 새로운 캐릭터 '춘식이' 화제
# 1 카카오프렌즈 '라이언' 유기묘 집사가 되다?! - 새로운 캐릭터 '춘식이'
# 2 수의사가 보는 동물 캐릭터] 카카오프렌즈 춘식이 2
# 3 카카오프렌즈 춘식이 얼굴형 그립톡 슬림 스위치스
# 4 수의사가 보는 동물 캐릭터] 카카오 프렌즈 춘식이
# 5 춘식이 미술관 찾았다...카카오프렌즈, 환기미술관과 특별 전시 | 한국경제
# 6 춘식이는 고양이 컬러링북 - 예스24
# 7 카카오프렌즈 춘식이와 죠르디 60CM 인형, 믿고 사는 즐거움 SSG.COM
# 8 카카오, 카카오프렌즈 '춘식이' X 프로야구구단 컬래버 굿즈 출시 | 카카오
# 9 춘식툰 시리즈2. 춘식이는 집순이 - 웹툰 | 카카오페이지
# 10 춘식 - 나무위키
# 11 고고싱 킥보드 인형_춘식이 - GS SHOP
# 12 씨스타(C-STAR)_캐릭터용품전문
# 13 카카오 프렌즈 춘식이] 수의사가 보는 고양이 춘식이 : 네이버 포스트
# 14 무료배송] 카카오프렌즈 춘식이 풉백 - 펫프렌즈
# 15 카카오, 카카오프렌즈 '춘식이' 데뷔 3주년 기념 프로젝트 시작 | 카카오
# 16 카카오프렌즈 신규IP '춘식이'
# 17 축구하는 춘식이랑 코리아팀 응원해요⚽ - YouTube
# 18 걷기왕 춘식이 만보기가 나왔어요 | 카카오페이 공식 블로그
# 19 Trend A Word #72] 춘식이요? 친구 이름이에요? 고양이라구요?
# 20 프렌즈온
# 21 Search Projects | Photos, videos, logos, illustrations and branding on  Behance
# 22 카카오 춘식이가 쓴 파리 여행 일기
# 23 카카오프렌즈 파트너(KAKAOFRIENDS PARTNERS) USB 춘식이 고구마 박스 가습기 600ml - 후기 | 무신사
# 24 춘식이는 라이언 만나기 전 어떻게 살았을까…첫 캐릭터 팬미팅
# 25 카카오프렌즈 춘식이와 죠르디 60CM - 이젠돌스
# 26 무료배송] 카카오프렌즈 춘식이 도어사인 2종 - 펫프렌즈
# 27 카카오프렌즈, 라이언&춘식 환상적 댄스 듀오로 데뷔해 | 카카오
# 28 SPC 배스킨라빈스, 카카오프렌즈와 '춘식이가 반할수박에' 출시 – SPC매거진
# 29 수의사가 보는 동물 캐릭터] 카카오프렌즈 춘식이 2
# 30 카카오프렌즈] 춘식이 패치 샤프 > 전체상품 > 핫트라인 홈페이지에 오신것을 환영합니다.
# 31 LGU+, 카카오프렌즈 '춘식이' 어린이용 스마트폰 론칭 :: 매일경제TV 뉴스
# 32 릴팡 카카오프렌즈 춘식이 스푼포크젓가락수저집세트 | 릴팡
# 33 제주에디션 감귤망을 든 춘식이 | JDC 면세점 - 제주국제자유도시개발센터
# 34 카카오프렌즈 USB 춘식이 고구마 박스 가습기 스위치스
# 35 카카오프렌즈, '춘식이' 굿즈 첫 출시
# 36 22개의 춘식이 아이디어 | 카카오프렌즈, 배경화면, 배경
# 37 카카오 '춘식이' 애니·만화 공개..."3주년 팬미팅도 연다" < 인프라 < 뉴스 < 기사본문 - 테크M
# 38 아이콘스 카카오프렌즈 춘식이 피규어 주차번호판 : 다나와 가격비교
# 39 춘식이 꿀잠 팔쿠션 - 캐샵
# 40 10x10: 카카오 춘식이 마우스패드 엄지척C29230
# 41 카카오 춘식이 관찰일기 - 더즈 인터랙티브
# 42 춘식이 과거는?…카카오, 애니메이션 '도도도 춘식이' 공개 | 서울경제
# 43 카카오프렌즈 춘식이 인형노즈워크 고구마상자 - 프렌즈온
# 44 SPECIAL] 춘식이 팬미팅 다시보기 | 카운트다운 ⏱️ - YouTube
# 45 갤럭시 버즈2 프로 춘식이 케이스 (옐로우) | GP-FPR177HINYK | Samaung 대한민국
# 46 카카오 춘식이 라이언 입양아!? 이유를 알려주마 : 네이버 블로그
# 47 춘식이 그림일기 (@Choonsik_diary) / X
# 48 카카오프렌즈(KAKAO FRIENDS) 알파카 바디 필로우_춘식이 - 후기 | 무신사
# 49 두산베어스샵 두산베어스 인형 V7 춘식이
# 50 춘식 (r62 판) - 나무위키
# 51 카카오프렌즈] 춘식이 젤펜과 봉투파일 세트 > 전체상품 > 핫트라인 홈페이지에 오신것을 환영합니다.
# 52 춘식이는 프렌즈 | 카카오웹툰
# 53 카카오뱅크, 롯데카드와 '춘식이 신용카드' 선봬 - 서울파이낸스
# 54 카카오게임즈 '프렌즈팝콘', 7주년 기념 '춘식이' 굿즈 쏜다 < 게임 < 산업 < 기사본문 - 파이낸셜투데이
# 55 춘식이 그림일기 – 엣취 : EDCHeee
# 56 춘식이와 아이브의 콜라보 '배춘'이를 아세요?
# 57 카카오프렌즈, 라이언의 반려묘 '춘식이' 굿즈 첫 출시 - 조선비즈
# 58 카카오, 카카오TV에서 '도도도 춘식이' 애니메이션 공개 | 카카오
# 59 2023 롯데자이언츠 인형 V3 춘식이]
# 60 카카오프렌즈 골프 - 베이직 전신네임택 - 춘식이
# 61 카카오페이, 춘식이 그려진 '신한카드 KaPick' 출시 - 매일일보
# 62 카카오뱅크, 인기 캐릭터 '춘식이'를 적용한 '카카오뱅크 우리카드' 선보여
# 63 KBO구단 X 춘식이 인형이 돌아옵니다. (9/22) | 다음스포츠
# 64 카카오 '라전무'·뜨는 '춘식이'…인플루언서로 키운다 | 연합뉴스
# 65 춘식이 실리콘 얼굴 파우치 | (주)에버겟 - 카카오프렌즈 문구/팬시/리빙 제품 총판업체
# 66 LG유플러스, 카카오 최고 인기 캐릭터 '춘식이' 키즈폰 단독 출시
# 67 춘식이 컴퓨터 아이콘 공유 : 네이버 블로그
# 68 안 살 수가 없네”… 9일 출시되는 스타벅스 '춘식이' 굿즈 (+사진) | 위키트리
# 69 카카오TV '도도도 춘식이' 애니, 공개 5시간여만에 100만 뷰(종합)
# 70 카카오 프렌즈 춘식이 인형 대형 60cm 동물 당일발송 - G마켓 모바일
# 71 춘식 - 나무위키
# 72 카카오프렌즈 춘식이 브릭 피규어 블루투스 스피커 - Frisbee
# 73 카카오프렌즈, 새 캐릭터 '춘식이' 굿즈 출시 < 게임·인터넷 < 기사본문 - 디지털투데이 (DigitalToday)
# 74 제주에디션 감귤망을 든 춘식이 | JDC 면세점 - 제주국제자유도시개발센터
# 75 수의사가 보는 동물 캐릭터] 카카오프렌즈 춘식이 2
# 76 카카오프렌즈]카카오프렌즈 춘식이 포토스티커 춘식이컷 : 롯데ON
# 77 카카오프렌즈 춘식이 앉아 실리콘 무드등 에스닷
# 78 문방구-카카오프렌즈 문구의 모든것
# 79 카카오 '라이언&춘식이' 댄스 듀오로 데뷔 - 파이낸셜뉴스
# 80 바람개비 방향제_춘식이 - 예스24
# 81 라이언 춘식이와 노을멍 > 배경화면 | 쿨엔조이
# 82 LG유플러스, 카카오 '춘식이' 키즈폰 단독 출시 - 정보통신신문
# 83 춘식이 좋아 Sticker - 춘식이 춘식 좋아 - Discover & Share GIFs
# 84 춘식이와 만난 빙그레 '고구마맛우유' 출시 - 엔터&라이프매거진 훅미업
# 85 바잇미 :: 카카오프렌즈 춘식이 메시지 와펜(겁이 많아서 짖어요)
# 86 카카오프렌즈 학용품 문구 세트1 춘식이 세트 문구세트 - 온오프조명
# 87 로카모빌리티, 카카오프렌즈 '춘식이' 로카모빌리티카드 신규 출시 - 시장경제
# 88 라이언과 춘식이의 첫만남부터🧡 춘식툰 역주행 TIME - YouTube
# 89 카드에 춘식이 있다" 신한카드, 카카오페이와 '카픽' 출시 - 머니S
# 90 무료배송] 카카오프렌즈 춘식이 슬링백 - 펫프렌즈
# 91 어떤 춘식이에 투표할까” 카카오메이커스, 사랑의열매 협업
# 92 카카오프렌즈 새 캐릭터 이름은 춘식이 : 네이버 블로그
# 93 카카오 라이언· 춘식이가 마리떼 프랑소와 저버와 만나면? - 한국면세뉴스
# 94 파리바게트 '호랑이탈 쓴 고양이 춘식이' 쿠션 한정 출시 - 뉴스핌
# 95 춘식이 방' 구경오세요”…카카오프렌즈 강남 스토어 리뉴얼 오픈
# 96 춘식이' '토심이' '망그러진 곰' 이모티콘 받으세요...카카오, 전 국민 보상 시작한다
# 97 춘식이의 MBTI는 무엇일까?
# 98 31개의 춘식이 아이디어 | 카카오프렌즈, 카카오, 배경화면
# 99 춘식이 피규어 키링 - 감도 깊은 취향 셀렉트샵 29CM
# 100 카카오프렌즈 차량용방향제 라이언 춘식이 2ml' 최저가 검색, 최저가 17,000원 - 할인 알림
# 101 SPC 배스킨라빈스, 라이언과 춘식이의 여름휴가 광고 영상 공개 < 일반경제 < 경제 < 기사본문 - 리버티코리아포스트
# 102 우리카드, 춘식이 담은 '카카오뱅크 우리카드' 출시 < 보도자료 < 금융 < 경제 < 기사본문 - 뉴스포스트
# 103 갤럭시 버즈2 프로 춘식이 케이스 (옐로우) | GP-FPR177HINYK | Samaung 대한민국
# 104 먹통 사과' 카카오, 이모티콘 3종 등 지급···믿을 건 '춘식이' - 경향신문
# 105 카카오프렌즈 춘식이 랜덤 도자기 소주잔 4P | SK스토아
# 106 알라딘: 춘식이는 고양이 컬러링북
# 107 제주에디션 하르방 춘식이 미니인형 | JDC 면세점 - 제주국제자유도시개발센터
# 108 아이콘스 카카오프렌즈 춘식이 스프링 얼굴 수첩 : 다나와 가격비교
# 109 춘식이의 일기: 라이언은 하루종일 뭘 할까? - 디자인 나침반
# 110 라이언, 춘식이 캐릭터...'카카오빵'으로 나온다
# 111 U+키즈폰 with 춘식이 | 제품 | Pinplay
# 112 카카오프렌즈 춘식이 슬림 케이스 - 오아시스마켓::믿을 수 있는 먹거리
# 113 아이브X춘식이, 이 조합 최고…깜찍한 잊게 만든 다크 매력 - MBN
# 114 춘식이 꿀잠 팔쿠션 - 캐샵
# 115 GS25, 카카오프렌즈 춘식이 등 다양한 컬래버 빼빼로 선봬 - 뉴스와이어
# 116 배스킨라빈스, 라이언&춘식이 협업 '라이언 망고 마카롱' 출시 - 시사캐스트
# 117 춘식이 Chunsik GIF - 춘식이 춘식 Chunsik - Discover & Share GIFs
# 118 신상품] 배스킨라빈스 '춘식이가 반할수박에' - 서울파이낸스
# 119 카카오프렌즈 파리에 가다 - 라이언, 춘식이 파리 여행
# 120 초등 안심 U+키즈폰 with 춘식이, 초등입학선물로 딱! 2월 구매 이벤트도 참여하세요
# 121 티몬 글로벌 홀세일 - 카카오프렌즈 춘식이 큐브인형 : Qoo10 Event
# 122 CEOSCOREDAILY
# 123 춘식이는 야옹
# 124 카카오프렌즈 춘식이 패치 샤프 - HOTTRACKS
# 125 Trend A Word #72] 춘식이요? 친구 이름이에요? 고양이라구요?
# 126 춘식이와 함께 하는 가을 나들이 카카오, 카카오프렌즈 도심관광 행사 | 아주경제
# 127 카카오프렌즈 춘식이 포켓 보조배터리 10000mAh | 개성상인 Tel:1544-8713 기념품제작,판촉물제작,굿즈제작,홍보물품제작
# 128 스타벅스 춘식이 한정판매 굿즈 출시 '판매처·상품종류는?' < 경제 < 뉴스 < 기사본문 - 시사매거진
# 129 춘식이 행운인형 - 예스24
# 130 갤럭시 S23 춘식이 버라이어티 케이스 (스카이블루) | GP-FPS911HIALK | Samsung 대한민국
# 131 요즘 춘식이가 인기라며 | 메이플 인벤
# 132 💝춘식이 인형 보조배터리 사전예약🎁 | 파리바게뜨
# 133 춘식이 방' 구경오세요”…카카오프렌즈 강남 스토어 리뉴얼 오픈
# 134 귀여움의 끝, 맥심 X 카카오프렌즈 춘식이 - 디에디트
# 135 카카오톡] 카톡 이벤트 신기능 '사랑해' 라이언💗춘식이 배경화면
# 136 직썰Why] 롯데카드, 꾸준한 '춘식이' 사랑 왜?
# 137 춘식이 서프라이즈 마이키링 - 메가마트몰
# 138 카카오프렌즈] 춘식이 젤펜 (1.0mm) > 전체상품 > 핫트라인 홈페이지에 오신것을 환영합니다.
# 139 카카오프렌즈 춘식이 미니 페이스 얼굴 쿠...
# 140 캐릭터특집] 카카오프렌즈 춘식이테마 피피티(ppt)템플릿 무료공유 : 네이버 블로그
# 141 춘식이 포토스티커 | (주)에버겟 - 카카오프렌즈 문구/팬시/리빙 제품 총판업체
# 142 카카오프렌즈 춘식이 칭찬해 선물 세트 - Funny:D 퍼니디
# 143 롯데카드, 춘식이 담긴 한정판 '카카오뱅크 카드' 출시
# 144 춘식이 새 이모티콘 받자"…카카오 '이모티콘 3종' 지급
# 145 카카오 캐릭터 IP에 관한 조금 자세한 이야기들 | 카카오
# 146 10x10: 드레스업인형_춘식이
# 147 릴팡 카카오프렌즈 춘식이 2단 도시락가방세트 | 릴팡
# 148 블라인드 | 블라블라: 카카오톡 춘식이 워치페이스
# 149 카카오프렌즈 춘식이 캐릭터 에코 접이식 시장가방 장바구니 610818 - 글루미 캐릭터몰
# 150 카카오프렌즈 춘식이 미니 플랫 펜슬 세트 춘식이펜+형광펜 2P+샤프
# 151 카카오프렌즈 춘식이 투명 데코 스티커 - 캐릭터 생활용품 팬시쇼핑몰 우사기몰
# 152 동서식품, '맥심X카카오프렌즈 춘식이 스페셜 패키지' 한정판 출시 - 브릿지경제
# 153 카카오프렌즈 얼굴형 무선 블루투스 이어폰(얼굴형 춘식이,얼굴형 라이언) - HOME&SHOPPING
# 154 카카오프렌즈 춘식이 카툰 Z플립4 ,3 ,1/2 슬림케이스 - 그리다마켓
# 155 카카오프렌즈 춘식이 라이언 어피치 포근한 순면 양면 타올발매트 - 더방긋
# 156 카카오프렌즈 춘식이 인형(제주도에디션) | 브랜드 중고거래 플랫폼, 번개장터
# 157 카카오프렌즈 춘식이 베이비필로우 인형 - 인터파크 쇼핑
# 158 아이콘스 카카오프렌즈 2023년 북마크 춘식이 다이어리 : 다나와 가격비교
# 159 춘식이 카카오프렌즈 소프트 키링,슈퍼8비트,캐릭터, 디자인쇼핑몰 바보사랑
# 160 옥션] 2024 춘식이 다이어리 1+1 (13,290원/무료) - 뽐뿌:뽐뿌게시판
# 161 카카오프렌즈 아이폰 춘식이 임팩트 디자인 케이스 모음전 - 모란카노
# 162 카카오프렌즈 피규어키링 DJ 춘식이 - 에누리 가격비교
# 163 춘식이 대학생 신학기 필수 아이템 선물 세트 - HOTTRACKS
# 164 오늘도 수고했다냥!” 춘식이가 전하는 귀여운 위로 - DIGITAL iNSIGHT 디지털 인사이트
# 165 카카오프렌즈 캐릭터 '라이언'과 '춘식이'가 스낵으로 < 이슈 < 생활경제 < 기사본문 - 이코노믹리뷰
# 166 카카오프렌즈 정품 춘식이 인형-11번가 모바일
# 167 춘식이 그림일기 on Twitter | 귀여운 동물 그림, 고양이 그림, 웃긴 밈
# 168 카카오프렌즈 춘식이 스트링 파우치 미니파우치 춘식이-아토즈몰, 믿고 사는 즐거움 SSG.COM
# 169 카카오 캐릭터 IP에 관한 조금 자세한 이야기들 | 카카오
# 170 춘식이 마우스패드 1개 - 현대Hmall
# 171 카카오프렌즈 애플워치 충전 거치대 - 춘식이 - Frisbee
# 172 춘식 (r447 판) - 나무위키
# 173 매력만점' 춘식이, 인천공항에 떴다…신세계免 '브릭피규어' 판매 - 머니투데이
# 174 카카오TV 도도도 춘식이 애니, 공개 5시간여만에 100만 뷰(종합) | 한국경제
# 175 gs춘식이 콜라 제로 - 음식/여행 - 에펨코리아
# 176 더팝리워즈에 춘식이 굿즈까지”…카카오뱅크, GS리테일과 26주적금 출시
# done
